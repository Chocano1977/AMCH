# %%
# Celda 1: Importaciones necesarias
import pandas as pd
from datetime import datetime

# Celda 2: Configuración de Spark con Delta Lake
from delta import configure_spark_with_delta_pip
from pyspark.sql import SparkSession

builder = SparkSession.builder.appName("DuplicadosDeltaLake") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
spark = configure_spark_with_delta_pip(builder).getOrCreate()

# Celda 3: Definición de la función para guardar en Delta Lake
def guardar_dataframe_en_deltalake(df_duplicados, nombre_df, ruta_base, spark_session):
    """
    Guarda un DataFrame de pandas en Delta Lake, añadiendo el nombre del dataframe y la fecha/hora actual al nombre del directorio.

    Args:
        df_pandas (pd.DataFrame): DataFrame de pandas a guardar.
        nombre_df (str): Nombre base del DataFrame.
        ruta_base (str): Ruta base donde guardar el fichero Delta Lake.
        spark_session (SparkSession): Sesión de Spark inicializada.
    """
    import os
    from datetime import datetime

    # Convertir pandas DataFrame a Spark DataFrame
    df_spark = spark_session.createDataFrame(df_duplicados)
    # Crear nombre único con fecha/hora
    fecha_hora = datetime.now().strftime("%Y%m%d_%H%M%S")
    nombre_fichero = f"{nombre_df}_duplicados_{fecha_hora}"
    ruta_salida = os.path.join(ruta_base, nombre_fichero)
    # Escribir en formato Delta Lake
    df_spark.write.format("delta").mode("overwrite").save(ruta_salida)
    print(f"Duplicados guardados en Delta Lake en: {ruta_salida}")

# Celda 4: Ejemplo de uso
# Crear un DataFrame de ejemplo
df = pd.DataFrame({
    'id': [1, 2, 2, 3, 4, 4, 4, 4],
    'valor': ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'g']
})

# Encontrar duplicados
duplicados = df[df.duplicated(subset=['id', 'valor'], keep=False)]

# Guardar duplicados en Delta Lake
# guardar_dataframe_en_deltalake(duplicados, "df", "/lakehouse/default/Files",# Celda 1: Importaciones necesarias
import pandas as pd
from datetime import datetime

# Celda 2: Configuración de Spark con Delta Lake
from delta import configure_spark_with_delta_pip
from pyspark.sql import SparkSession

builder = SparkSession.builder.appName("DuplicadosDeltaLake") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
spark = configure_spark_with_delta_pip(builder).getOrCreate()

# Celda 3: Definición de la función para guardar en Delta Lake
def guardar_dataframe_en_deltalake(df_duplicados, nombre_df, ruta_base, spark_session):
    """
    Guarda un DataFrame de pandas en Delta Lake, añadiendo el nombre del dataframe y la fecha/hora actual al nombre del directorio.

    Args:
        df_pandas (pd.DataFrame): DataFrame de pandas a guardar.
        nombre_df (str): Nombre base del DataFrame.
        ruta_base (str): Ruta base donde guardar el fichero Delta Lake.
        spark_session (SparkSession): Sesión de Spark inicializada.
    """
    import os
    from datetime import datetime

    # Convertir pandas DataFrame a Spark DataFrame
    df_spark = spark_session.createDataFrame(df_duplicados)
    # Crear nombre único con fecha/hora
    fecha_hora = datetime.now().strftime("%Y%m%d_%H%M%S")
    nombre_fichero = f"{nombre_df}_duplicados_{fecha_hora}"
    ruta_salida = os.path.join(ruta_base, nombre_fichero)
    # Escribir en formato Delta Lake
    df_spark.write.format("delta").mode("overwrite").save(ruta_salida)
    print(f"Duplicados guardados en Delta Lake en: {ruta_salida}")

# Celda 4: Ejemplo de uso
# Crear un DataFrame de ejemplo
df = pd.DataFrame({
    'id': [1, 2, 2, 3, 4, 4, 4, 4],
    'valor': ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'g']
})

# Encontrar duplicados
duplicados = df[df.duplicated(subset=['id', 'valor'], keep=False)]

# Guardar duplicados en Delta Lake
 guardar_dataframe_en_deltalake(duplicados, "df", "/lakehouse/default/Files",spark) spark)
# Nota: Descomentar la línea anterior para ejecutar el guardado en Delta Lake.
# Out:
#   Cell In[1], line 97
#     guardar_dataframe_en_deltalake(duplicados, "df", "/lakehouse/default/Files",spark) spark)
#     ^
# IndentationError: unexpected indent
