# %%
@json('[
   {
    "sourceSchema": "CONT_OWN",
    "sourceTable": "CONT_TCOD_CONTRATO",
    "targetSchema": "staging",
    "targetTable": "CONT_TCOD_CONTRATO",
    "filter": "COD_OPERADOR=''BBG''"  
   },
   {
    "sourceSchema": "CONT_OWN",
    "sourceTable": "CONT_TSOLIC",
    "targetSchema": "staging",
    "targetTable": "CONT_TSOLIC",
    "filter": "FEC_ALTA BETWEEN TO_DATE('{{inicial}}', 'YYYYMMDD') AND TO_DATE('{{final}}', 'YYYYMMDD') OR FEC_MODI BETWEEN TO_DATE('{{inicial}}', 'YYYYMMDD') AND TO_DATE('{{final}}', 'YYYYMMDD')"
  },
  {
    "sourceSchema": "CONT_OWN",
    "sourceTable": "CONT_TLINEA_SERV_SOLIC",
    "targetSchema": "staging",
    "targetTable": "CONT_TLINEA_SERV_SOLIC",
    "filter": ""
  },
  {
     "sourceSchema": "CONT_OWN",
     "sourceTable": "CONT_TADENDA",
     "targetSchema": "staging",
     "targetTable": "CONT_TADENDA",
     "filter": ""
   }
  ]'
)

# %% [markdown]
# vg_fec_actual='20240917'
# vg_contrato='BBG'
#
# "filter": "COD_OPERADOR=''',variables('vg_contrato'),'''"
#
# ' WHERE (',
#     '(TO_CHAR(TRUNC(FEC_ALTA),''YYYYMMDD'') > TO_CHAR(TO_DATE(''', variables('vg_initDate'), ''', ''YYYYMMDD''), ''YYYYMMDD'') ',
#     'AND TO_CHAR(TRUNC(FEC_ALTA),''YYYYMMDD'') <= TO_CHAR(TO_DATE(''', variables('vg_endDate'), ''', ''YYYYMMDD''), ''YYYYMMDD'')) ',
#     'OR ',
#     '(TO_CHAR(TRUNC(FEC_MODI),''YYYYMMDD'') > TO_CHAR(TO_DATE(''', variables('vg_initDate'), ''', ''YYYYMMDD''), ''YYYYMMDD'') ',
#     'AND TO_CHAR(TRUNC(FEC_MODI),''YYYYMMDD'') <= TO_CHAR(TO_DATE(''', variables('vg_endDate'), ''', ''YYYYMMDD''), ''YYYYMMDD''))',
#   ')'

# %%
@json('[
   {
    "sourceSchema": "CONT_OWN",
    "sourceTable": "CONT_TCOD_CONTRATO",
    "targetSchema": "staging",
    "targetTable": "CONT_TCOD_CONTRATO",
    "filter": ""
   },
   {
    "sourceSchema": "CONT_OWN",
    "sourceTable": "CONT_TSOLIC",
    "targetSchema": "staging",
    "targetTable": "CONT_TSOLIC",
    "filter": "FEC_ALTA BETWEEN TO_DATE('{{inicial}}', 'YYYYMMDD') AND TO_DATE('{{final}}', 'YYYYMMDD') OR FEC_MODI BETWEEN TO_DATE('{{inicial}}', 'YYYYMMDD') AND TO_DATE('{{final}}', 'YYYYMMDD')"
  },
  {
    "sourceSchema": "CONT_OWN",
    "sourceTable": "CONT_TLINEA_SERV_SOLIC",
    "targetSchema": "staging",
    "targetTable": "CONT_TLINEA_SERV_SOLIC",
    "filter": "FEC_ALTA BETWEEN TO_DATE('{{inicial}}', 'YYYYMMDD') AND TO_DATE('{{final}}', 'YYYYMMDD') OR FEC_MODI BETWEEN TO_DATE('{{inicial}}', 'YYYYMMDD') AND TO_DATE('{{final}}', 'YYYYMMDD')"
  },
  {
     "sourceSchema": "CONT_OWN",
     "sourceTable": "CONT_TADENDA",
     "targetSchema": "staging",
     "targetTable": "CONT_TADENDA",
     "filter": ""
   }
  ]'
)

# %%
@concat(
  'SELECT * FROM ',
  item().tabla,
  ' WHERE ',
  replace(
    replace(item().whereTemplate, '{{inicial}}', variables('vg_inicial')),
    '{{final}}', variables('vg_final')
  )
)

# %%
@json('[
  {
  "sourceSchema": "CONT_OWN",
	"sourceTable": "CONT_TADENDA",
	"targetSchema": "staging",
  "targetTable": "CONT_TADENDA",
  "filter": "FEC_ALTA BETWEEN TO_DATE(''{{inicial}}'', ''YYYYMMDD'') AND TO_DATE(''{{final}}'', ''YYYYMMDD'') OR FEC_MODI BETWEEN TO_DATE(''{{inicial}}'', ''YYYYMMDD'') AND TO_DATE(''{{final}}'', ''YYYYMMDD'')"
  },
  {
  "sourceSchema": "CONT_OWN",
  "sourceTable": "CONT_TSOLIC",
  "targetSchema": "staging",
  "targetTable": "CONT_TSOLIC",
  "filter": "FEC_ALTA BETWEEN TO_DATE(''{{inicial}}'', ''YYYYMMDD'') AND TO_DATE(''{{final}}'', ''YYYYMMDD'') OR FEC_MODI BETWEEN TO_DATE(''{{inicial}}'', ''YYYYMMDD'') AND TO_DATE(''{{final}}'', ''YYYYMMDD'')"
  },
  {
  "sourceSchema": "CONT_OWN",
  "sourceTable": "CONT_TLINEA_SERV_SOLIC",
  "targetSchema": "staging",
  "targetTable": "CONT_TLINEA_SERV_SOLIC",
  "filter": "FEC_ALTA BETWEEN TO_DATE(''{{inicial}}'', ''YYYYMMDD'') AND TO_DATE(''{{final}}'', ''YYYYMMDD'') OR FEC_MODI BETWEEN TO_DATE(''{{inicial}}'', ''YYYYMMDD'') AND TO_DATE(''{{final}}'', ''YYYYMMDD'')"
  },
  {
  "sourceSchema": "CONT_OWN",
  "sourceTable": "CONT_TCOD_CONTRATO",
  "targetSchema": "staging",
  "targetTable": "CONT_TCOD_CONTRATO",
  "filter": ""
  },
  {
  "sourceSchema": "DREF_OWN",
	"sourceTable": "DREF_TSUJETO",
	"targetSchema": "staging",
  "targetTable": "DREF_TSUJETO",
  "filter": ""
  },
  {
  "sourceSchema": "DREF_OWN",
	"sourceTable": "DREF_TINFR",
	"targetSchema": "staging",
  "targetTable": "DREF_TINFR",
  "filter": ""
  },
  {
  "sourceSchema": "DREF_OWN",
	"sourceTable": "DREF_TPUNTO_CONEX",
	"targetSchema": "staging",
  "targetTable": "DREF_TPUNTO_CONEX",
  "filter": ""
  },
  {
  "sourceSchema": "DREF_OWN",
	"sourceTable": "DREF_TBUQ_METAN",
	"targetSchema": "staging",
  "targetTable": "DREF_TBUQ_METAN",
  "filter": ""
  },
  {
  "sourceSchema": "CONT_OWN",
  "sourceTable": "CONT_TSUBASTA",
  "targetSchema": "staging",
  "targetTable": "CONT_TSUBASTA",
  "filter": "FEC_ALTA BETWEEN TO_DATE(''{{inicial}}'', ''YYYYMMDD'') AND TO_DATE(''{{final}}'', ''YYYYMMDD'') OR FEC_MODI BETWEEN TO_DATE(''{{inicial}}'', ''YYYYMMDD'') AND TO_DATE(''{{final}}'', ''YYYYMMDD'')"
  },
  {
  "sourceSchema": "CONT_OWN",
  "sourceTable": "CONT_TORIGEN",
  "targetSchema": "staging",
  "targetTable": "CONT_TORIGEN",
  "filter": "FEC_ALTA BETWEEN TO_DATE(''{{inicial}}'', ''YYYYMMDD'') AND TO_DATE(''{{final}}'', ''YYYYMMDD'') OR FEC_MODI BETWEEN TO_DATE(''{{inicial}}'', ''YYYYMMDD'') AND TO_DATE(''{{final}}'', ''YYYYMMDD'')"
  },
  {
  "sourceSchema": "CONT_OWN",
  "sourceTable": "CONT_TPRODUCTO",
  "targetSchema": "staging",
  "targetTable": "CONT_TPRODUCTO",
  "filter": "FEC_ALTA BETWEEN TO_DATE(''{{inicial}}'', ''YYYYMMDD'') AND TO_DATE(''{{final}}'', ''YYYYMMDD'') OR FEC_MODI BETWEEN TO_DATE(''{{inicial}}'', ''YYYYMMDD'') AND TO_DATE(''{{final}}'', ''YYYYMMDD'')"
  }
 ]'
)
